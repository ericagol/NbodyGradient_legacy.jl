# %%
# Tests of amat.jl and init_nbody_test.jl
# Plot at the bottom is the current position of the body and a circular orbital path

# %%
using DelimitedFiles
include("../../src/ttv.jl")

global elements = readdlm("../elements.txt",',',skipstart=1)
global t0 = 7257.9215525

# IC for TRAPPIST-1
IC = [8,"1,1,1,1,1,1,1,1"]
n_body = IC[1]
jac_init = zeros(Float64,7*n_body,7*n_body)
""""""

# %%
include("../../src/init_nbody_test.jl")
x,v = init_nbody(elements,t0,IC)
x

# %%
using Plots
pyplot()

# %%
scatter(x[1,:],x[3,:])

# %%
r = zeros(Float64,8)
for j in 1:8
    r[j] = LinearAlgebra.norm([x[1,j],x[3,j]])
end
r
# Out:
# 8-element Array{Float64,1}:
#  6.5761007178788056e-6
#  0.025134475520352747
#  0.03595579791583456
#  0.04922053250479172
#  0.06537076168942721
#  0.08598939169740127
#  0.10474162115841945
#  0.14049839614724105

# %%
x = zeros(Float64,length(0:0.01:2*pi))
y = zeros(Float64,length(0:0.01:2*pi))
using LinearAlgebra

for k in 1:8
    index = 1
    for i in 0:0.01:2*pi
        x[index] = r[k]*(cos(i))
        y[index] = r[k]*(sin(i))
        index += 1
    end
    plot!(x,y,aspect_ratio=1)
end
plot!()
# Out:
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = py_add_series(::Plots.Plot{Plots.PyPlotBackend}, ::Plots.Series) at pyplot.jl:443
# └ @ Plots /Users/zllangford/.julia/packages/Plots/QYETN/src/backends/pyplot.jl:443
# ┌ Warning: `getindex(o::PyObject, s::Symbol)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o.s` instead of `o[:s]`.
# │   caller = _before_layout_calcs(::Plots.Plot{Plots.PyPlotBackend}) at pyplot.jl:1134
# └ @ Plots /Users/zllangford/.julia/packages/Plots/QYETN/src/backends/pyplot.jl:1134
